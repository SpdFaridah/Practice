# %% [markdown]
# <a href="https://colab.research.google.com/github/SpdFaridah/Practice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Guess the number game

# %%
num= 67
while True :
  guess= int(input("Enter any two digit number:"))
  if guess == num :
    print("congratulations")
    break
  else :
    print("try again")
# Out:
# Enter any two digit number:23
# try again
# Enter any two digit number:67
# congratulations

# %%
num=67

while True:
  guess= int(input("Guess the hidden num: "))
  if guess==num:
    print("Congratulations")
    break
  else:
    print("Try again")
